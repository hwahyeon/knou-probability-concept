# %% [markdown]
# ## 제7장

# %%
#install.packages("mvtnorm")
library(mvtnorm)
# Out:
# The downloaded binary packages are in
# 	/var/folders/qq/r_7jy6q141b8jt24d32g75tw0000gn/T//RtmpXra5XJ/downloaded_packages

# %%
x = seq(0,6, length=51)
y = seq(-1,11, length=51)
f = matrix(0, nrow=length(x), ncol=length(y))
m = c(3,5)
S = matrix(c(1,-1,-1,4), nrow=2, ncol=2)
# 결합확률밀도함수의 계산
 for (i in 1:length(x)) 
   for (j in 1:length(y))
      f[i,j] = dmvnorm(c(x[i], y[j]), mean=m, sigma=S)

# 3차원 그림 그리기
persp(x, y, f)
# Out:
# plot without title

# %%
# 다항분포의 확률 계산
dmultinom(c(3,5,2), size=10, prob=c(0.25,0.5,0.25))

# 다항분포에서 난수 생성
rmultinom(n=5, size=10, prob=c(0.25,0.5,0.25))
# Out:
# [1] 0.0769043
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 3    2    2    4    2
# [2,] 5    6    3    3    6
# [3,] 2    2    5    3    2
